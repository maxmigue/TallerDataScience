# %% [markdown]
# <a href="https://colab.research.google.com/github/maxmigue/TallerDataScience/blob/main/ProyectoU1_TDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ruta del archivo .log
ruta = "/content/drive/MyDrive/Utal/TALLER CIENCIA DE DATOS/Proyectos/Unidad 1/MHEALTH DATASET/mHealth_subject1.log"

# Definir nombres de columnas
columnas = [
    "chest_acc_x", "chest_acc_y", "chest_acc_z",
    "ecg_1", "ecg_2",
    "ankle_acc_x", "ankle_acc_y", "ankle_acc_z",
    "ankle_gyro_x", "ankle_gyro_y", "ankle_gyro_z",
    "ankle_mag_x", "ankle_mag_y", "ankle_mag_z",
    "arm_acc_x", "arm_acc_y", "arm_acc_z",
    "arm_gyro_x", "arm_gyro_y", "arm_gyro_z",
    "arm_mag_x", "arm_mag_y", "arm_mag_z",
    "label"
]

# Leer el archivo log (separado por espacios o tabs)
df = pd.read_csv(ruta, sep=r"\s+", header=None, names=columnas)

# Ver primeras filas
print(df.head())

# Ver cantidad de filas
print(df.shape)

# Ver tipo de variables
print(df.dtypes)

print("\n--- Medidas estadísticas ---")
print(df.describe())

# 4. Distribución de variables (histogramas)
df.hist(figsize=(15, 12), bins=30)
plt.suptitle("Distribución de variables")
plt.show()

# 5. Correlación entre variables
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), cmap="coolwarm", annot=False)
plt.title("Matriz de correlación")
plt.show()

# 6. Visualización de algunas señales (ejemplo)
plt.figure(figsize=(12, 6))
plt.plot(df["ecg_1"][:1000], label="ECG Lead 1")
plt.plot(df["ecg_2"][:1000], label="ECG Lead 2")
plt.title("Ejemplo de señal ECG (primeras 1000 muestras)")
plt.legend()
plt.show()
# Out:
#    chest_acc_x  chest_acc_y  chest_acc_z     ecg_1     ecg_2  ankle_acc_x  \
# 0      -9.8184     0.009971      0.29563  0.004186  0.004186       2.1849
# 1      -9.8489     0.524040      0.37348  0.004186  0.016745       2.3876
# 2      -9.6602     0.181850      0.43742  0.016745  0.037677       2.4086
# 3      -9.6507     0.214220      0.24033  0.079540  0.117220       2.1814
# 4      -9.7030     0.303890      0.31156  0.221870  0.205130       2.4173
#
#    ankle_acc_y  ankle_acc_z  ankle_gyro_x  ankle_gyro_y  ...  arm_acc_x  \
# 0      -9.6967      0.63077      0.103900      -0.84053  ...    -8.6499
# 1      -9.5080      0.68389      0.085343      -0.83865  ...    -8.6275
# 2      -9.5674      0.68113      0.085343      -0.83865  ...    -8.5055
# 3      -9.4301      0.55031      0.085343      -0.83865  ...    -8.6279
# 4      -9.3889      0.71098      0.085343      -0.83865  ...    -8.7008
#
#    arm_acc_y  arm_acc_z  arm_gyro_x  arm_gyro_y  arm_gyro_z  arm_mag_x  \
# ...
